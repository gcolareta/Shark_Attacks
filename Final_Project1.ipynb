# %%
import pandas as pd
import numpy as np
import time

# %%
# Dependencies to connect Postgress with Jupyter notebook. Source:https://www.skytowner.com/explore/comprehensive_guide_on_importing_tables_from_postgresql_as_pandas_dataframes
from sqlalchemy import create_engine

# %%
# Connecting the data base to Jupyter notebook
engine = create_engine('postgresql://postgres:Ayuda52!@localhost:5432/Sharks')

# %%
# Reading table Hemisphere
hemispheres_df=pd.read_sql_query('SELECT * FROM Hemisphere;', con=engine)

# %%
hemispheres_df.head(100)
# Out:
#    hemisph                              country
# 0    South                    Admiralty Islands
# 1   North                           Afghanistan
# 2    North                Akrotiri and Dhekelia
# 3    North                              Albania
# 4    North                              Algeria
# ..     ...                                  ...
# 95   South  French Southern and Antarctic Lands
# 96   South                                Gabon
# 97   South                    Galapagos Islands
# 98  North                               Georgia
# 99   North                              Germany
#
# [100 rows x 2 columns]

# %%
hemispheres_df.dtypes
# Out:
# hemisph    object
# country    object
# dtype: object

# %%
path = 'attacks.csv'

# %%
# Reading attacks dataset. Source: https://stackoverflow.com/questions/42339876/error-unicodedecodeerror-utf-8-codec-cant-decode-byte-0xff-in-position-0-in
attacks_raw_df = pd.read_csv(path, encoding='cp1252')

# %%
attacks_raw_df
# Out:
#                  Country Case_Number         Date    Year        Type  \
# 0                    USA  2018.06.25    6/25/2018  2018.0     Boating
# 1                    USA  2018.06.18    6/18/2018  2018.0  Unprovoked
# 2                    USA  2018.06.09     6/9/2018  2018.0     Invalid
# 3              AUSTRALIA  2018.06.08     6/8/2018  2018.0  Unprovoked
# 4                 MEXICO  2018.06.04     6/4/2018  2018.0    Provoked
# ...                  ...         ...          ...     ...         ...
# 6297           AUSTRALIA     ND.0005  Before 1903     0.0  Unprovoked
# 6298           AUSTRALIA     ND.0004  Before 1903     0.0  Unprovoked
# 6299                 USA     ND.0003    1900-1905     0.0  Unprovoked
# 6300              PANAMA     ND.0002    1883-1889     0.0  Unprovoked
# 6301  CEYLON (SRI LANKA)     ND.0001    1845-1853     0.0  Unprovoked
#
#                    Area                             Location      Activity  \
# ...

# %%
# List the columns
attacks_raw_df.columns
# Out:
# Index(['Country', 'Case_Number', 'Date', 'Year', 'Type', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal_Y_N', 'Time',
#        'Species ', 'Investigator_ or_ Source', 'pdf', 'href'],
#       dtype='object')

# %%
attacks1_df= attacks_raw_df.drop(["pdf","href",'Investigator_ or_ Source',"Name","Case_Number"], axis=1)

# %%
attacks1_df
# Out:
#                  Country         Date    Year        Type               Area  \
# 0                    USA    6/25/2018  2018.0     Boating         California
# 1                    USA    6/18/2018  2018.0  Unprovoked            Georgia
# 2                    USA     6/9/2018  2018.0     Invalid             Hawaii
# 3              AUSTRALIA     6/8/2018  2018.0  Unprovoked    New South Wales
# 4                 MEXICO     6/4/2018  2018.0    Provoked             Colima
# ...                  ...          ...     ...         ...                ...
# 6297           AUSTRALIA  Before 1903     0.0  Unprovoked  Western Australia
# 6298           AUSTRALIA  Before 1903     0.0  Unprovoked  Western Australia
# 6299                 USA    1900-1905     0.0  Unprovoked     North Carolina
# 6300              PANAMA    1883-1889     0.0  Unprovoked                NaN
# 6301  CEYLON (SRI LANKA)    1845-1853     0.0  Unprovoked   Eastern Province
#
# ...

# %%
attacks1_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6302 entries, 0 to 6301
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Country    6252 non-null   object
#  1   Date       6302 non-null   object
#  2   Year       6300 non-null   float64
#  3   Type       6298 non-null   object
#  4   Area       5847 non-null   object
#  5   Location   5762 non-null   object
#  6   Activity   5758 non-null   object
#  7   Sex        5737 non-null   object
#  8   Age        3471 non-null   object
#  9   Injury     6274 non-null   object
#  10  Fatal_Y_N  5763 non-null   object
#  11  Time       2948 non-null   object
#  12  Species    3464 non-null   object
# dtypes: float64(1), object(12)
# memory usage: 640.2+ KB

# %%
# Keep only unprovoked attacks
unprovoked_attacks_df = attacks1_df[attacks1_df['Type'] == "Unprovoked"]

# %%
unprovoked_attacks_df
# Out:
#                  Country         Date    Year        Type               Area  \
# 1                    USA    6/18/2018  2018.0  Unprovoked            Georgia
# 3              AUSTRALIA     6/8/2018  2018.0  Unprovoked    New South Wales
# 5              AUSTRALIA     6/3/2018  2018.0  Unprovoked    New South Wales
# 6                 BRAZIL     6/3/2018  2018.0  Unprovoked         Pernambuco
# 7                    USA    5/27/2018  2018.0  Unprovoked            Florida
# ...                  ...          ...     ...         ...                ...
# 6297           AUSTRALIA  Before 1903     0.0  Unprovoked  Western Australia
# 6298           AUSTRALIA  Before 1903     0.0  Unprovoked  Western Australia
# 6299                 USA    1900-1905     0.0  Unprovoked     North Carolina
# 6300              PANAMA    1883-1889     0.0  Unprovoked                NaN
# 6301  CEYLON (SRI LANKA)    1845-1853     0.0  Unprovoked   Eastern Province
#
# ...

# %%
unprovoked_attacks_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4595 entries, 1 to 6301
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Country    4562 non-null   object
#  1   Area       4315 non-null   object
#  2   Location   4248 non-null   object
#  3   Date       4595 non-null   object
#  4   Month      0 non-null      float64
#  5   Year       4594 non-null   float64
#  6   Type       4595 non-null   object
#  7   Activity   4263 non-null   object
#  8   Injury     4578 non-null   object
#  9   Fatal_Y_N  4589 non-null   object
#  10  Species    0 non-null      float64
#  11  Time       2459 non-null   object
#  12  Sex        0 non-null      float64
#  13  Age        2863 non-null   object
# dtypes: float64(4), object(10)
# memory usage: 538.5+ KB

# %%
# Add Month column to extract the month of the attack
unprovoked_attacks_df['Month'] = ''
# Out:
# C:\Users\vicae\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
unprovoked_attacks_df
# Out:
#                  Country         Date    Year        Type               Area  \
# 1                    USA    6/18/2018  2018.0  Unprovoked            Georgia
# 3              AUSTRALIA     6/8/2018  2018.0  Unprovoked    New South Wales
# 5              AUSTRALIA     6/3/2018  2018.0  Unprovoked    New South Wales
# 6                 BRAZIL     6/3/2018  2018.0  Unprovoked         Pernambuco
# 7                    USA    5/27/2018  2018.0  Unprovoked            Florida
# ...                  ...          ...     ...         ...                ...
# 6297           AUSTRALIA  Before 1903     0.0  Unprovoked  Western Australia
# 6298           AUSTRALIA  Before 1903     0.0  Unprovoked  Western Australia
# 6299                 USA    1900-1905     0.0  Unprovoked     North Carolina
# 6300              PANAMA    1883-1889     0.0  Unprovoked                NaN
# 6301  CEYLON (SRI LANKA)    1845-1853     0.0  Unprovoked   Eastern Province
#
# ...

# %%
# Reorder columns
unprovoked_attacks_df = unprovoked_attacks.reindex(columns=['Country','Area', 'Location', 'Date', 'Month', 'Year', 'Type',  
                                        'Activity', 'Injury', 'Fatal_Y_N', 'Species', 'Time', 'Sex', 'Age'])

# %%
unprovoked_attacks_df
# Out:
#                  Country               Area  \
# 1                    USA            Georgia
# 3              AUSTRALIA    New South Wales
# 5              AUSTRALIA    New South Wales
# 6                 BRAZIL         Pernambuco
# 7                    USA            Florida
# ...                  ...                ...
# 6297           AUSTRALIA  Western Australia
# 6298           AUSTRALIA  Western Australia
# 6299                 USA     North Carolina
# 6300              PANAMA                NaN
# 6301  CEYLON (SRI LANKA)   Eastern Province
#
#                                                Location         Date  Month  \
# 1                        St. Simon Island, Glynn County    6/18/2018    NaN
# 3                                    Arrawarra Headland     6/8/2018    NaN
# 5                                    Flat Rock, Ballina     6/3/2018    NaN
# 6                                 Piedade Beach, Recife     6/3/2018    NaN
# ...

# %%
unprovoked_attacks_df.tail(10)
# Out:
#                  Country               Area  \
# 6292                 USA             Hawaii
# 6293           AUSTRALIA                NaN
# 6294           AUSTRALIA                NaN
# 6295           AUSTRALIA                NaN
# 6296           AUSTRALIA    New South Wales
# 6297           AUSTRALIA  Western Australia
# 6298           AUSTRALIA  Western Australia
# 6299                 USA     North Carolina
# 6300              PANAMA                NaN
# 6301  CEYLON (SRI LANKA)   Eastern Province
#
#                                  Location         Date  Month  Year  \
# 6292                                 Puna   Circa 1862    NaN   0.0
# 6293                                  NaN  Before 1906    NaN   0.0
# 6294                                  NaN  Before 1906    NaN   0.0
# 6295                                  NaN  Before 1906    NaN   0.0
# 6296                                       Before 1906    NaN   0.0
# ...

# %%
unprovoked_attacks_df["Year"]
# Out:
# 1       2018.0
# 3       2018.0
# 5       2018.0
# 6       2018.0
# 7       2018.0
#          ...
# 6297       0.0
# 6298       0.0
# 6299       0.0
# 6300       0.0
# 6301       0.0
# Name: Year, Length: 4595, dtype: float64

# %%
for column in unprovoked_attacks_df.columns:
    print(column, unprovoked_attacks_df[column].isnull().sum())
# Out:
# Country 33
# Area 280
# Location 347
# Date 0
# Month 4595
# Year 1
# Type 0
# Activity 332
# Injury 17
# Fatal_Y_N 6
# Species 4595
# Time 2136
# Sex 4595
# Age 1732

# %%
unprovoked_attacks_df["Species"]
# Out:
# 1      NaN
# 3      NaN
# 5      NaN
# 6      NaN
# 7      NaN
#         ..
# 6297   NaN
# 6298   NaN
# 6299   NaN
# 6300   NaN
# 6301   NaN
# Name: Species, Length: 4595, dtype: float64

# %%
unprovoked_attacks_df.head(10)
# Out:
#          Country                   Area  \
# 1            USA                Georgia
# 3      AUSTRALIA        New South Wales
# 5      AUSTRALIA        New South Wales
# 6         BRAZIL             Pernambuco
# 7            USA                Florida
# 8            USA                Florida
# 9            USA                Florida
# 11           USA         South Carolina
# 12           USA         South Carolina
# 15  SOUTH AFRICA  Eastern Cape Province
#
#                                              Location       Date  Month  \
# 1                      St. Simon Island, Glynn County  6/18/2018    NaN
# 3                                  Arrawarra Headland   6/8/2018    NaN
# 5                                  Flat Rock, Ballina   6/3/2018    NaN
# 6                               Piedade Beach, Recife   6/3/2018    NaN
# 7   Lighhouse Point Park, Ponce Inlet, Volusia County  5/27/2018    NaN
# 8                        Cocoa Beach, Brevard  County  5/26/2018    NaN
# ...
