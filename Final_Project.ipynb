# %%
import pandas as pd
import numpy as np
import time

# %%
path = 'attacks.csv'

# %%
# Reading attacks dataset. Source: https://stackoverflow.com/questions/42339876/error-unicodedecodeerror-utf-8-codec-cant-decode-byte-0xff-in-position-0-in
attacks_raw_df = pd.read_csv(path, encoding='cp1252')

# %%
attacks_raw_df
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
# Drop irrelevant columns
attacks_raw2_df = attacks_raw_df.drop(
    ['Name', 'Investigator or Source', 'pdf', 'href formula', 'href', 'Case Number.1', 'Case Number.2', 
     'original order', 'Unnamed: 22', 'Unnamed: 23'], axis=1)

# %%
attacks_raw2_df.head(10)
# Out:
#     Case Number         Date    Year        Type    Country             Area  \
# 0    2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1    2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2    2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3    2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4    2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
# 5  2018.06.03.b  03-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 6  2018.06.03.a  03-Jun-2018  2018.0  Unprovoked     BRAZIL       Pernambuco
# 7    2018.05.27  27-May-2018  2018.0  Unprovoked        USA          Florida
# 8  2018.05.26.b  26-May-2018  2018.0  Unprovoked        USA          Florida
# 9  2018.05.26.a  26-May-2018  2018.0  Unprovoked        USA          Florida
#
#                                             Location      Activity Sex   Age  \
# ...

# %%
# Keep only unprovoked attacks
unprovoked_attacks = attacks_raw2_df[attacks_raw2_df['Type'] == "Unprovoked"]

# %%
unprovoked_attacks.head(10)
# Out:
#      Case Number         Date    Year        Type       Country  \
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked           USA
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked     AUSTRALIA
# 5   2018.06.03.b  03-Jun-2018  2018.0  Unprovoked     AUSTRALIA
# 6   2018.06.03.a  03-Jun-2018  2018.0  Unprovoked        BRAZIL
# 7     2018.05.27  27-May-2018  2018.0  Unprovoked           USA
# 8   2018.05.26.b  26-May-2018  2018.0  Unprovoked           USA
# 9   2018.05.26.a  26-May-2018  2018.0  Unprovoked           USA
# 11    2018.05.21  21-May-2018  2018.0  Unprovoked           USA
# 12  2018.05.13.b  13-May-2018  2018.0  Unprovoked           USA
# 15    2018.05.12  12-May-2018  2018.0  Unprovoked  SOUTH AFRICA
#
#                      Area                                           Location  \
# 1                 Georgia                     St. Simon Island, Glynn County
# 3         New South Wales                                 Arrawarra Headland
# ...

# %%
# Add Month column to extract the month of the attack
unprovoked_attacks['Month'] = ''
# Out:
# /Users/giovannacolareta/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
unprovoked_attacks.head(5)
# Out:
#     Case Number         Date    Year        Type    Country             Area  \
# 1    2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 3    2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 5  2018.06.03.b  03-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 6  2018.06.03.a  03-Jun-2018  2018.0  Unprovoked     BRAZIL       Pernambuco
# 7    2018.05.27  27-May-2018  2018.0  Unprovoked        USA          Florida
#
#                                             Location      Activity Sex   Age  \
# 1                     St. Simon Island, Glynn County      Standing    F   11
# 3                                 Arrawarra Headland       Surfing    M  NaN
# 5                                 Flat Rock, Ballina  Kite surfing    M  NaN
# 6                              Piedade Beach, Recife      Swimming    M   18
# 7  Lighhouse Point Park, Ponce Inlet, Volusia County       Fishing    M   52
#
# ...

# %%
# Reorder columns
unprovoked_attacks = unprovoked_attacks.reindex(columns=['Case Number', 'Date', 'Month', 'Year', 'Type', 'Country', 'Area', 'Location',
                                        'Activity', 'Sex', 'Age', 'Injury', 'Fatal (Y/N)', 'Time', 'Species']
                                               )

# %%
unprovoked_attacks
