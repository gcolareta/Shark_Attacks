# %%
import pandas as pd
import numpy as np
import time

# %%
# Dependencies to connect Postgress with Jupyter notebook. Source:https://www.skytowner.com/explore/comprehensive_guide_on_importing_tables_from_postgresql_as_pandas_dataframes
from sqlalchemy import create_engine

# %%
# Connecting the data base to Jupyter notebook
engine = create_engine('postgresql://postgres:Ayuda52!@localhost:5432/Sharks')

# %%
# Reading table Hemisphere
df=pd.read_sql_query('SELECT * FROM merged_unprovoked;', con=engine)

# %%
df.head(100)
# Out:
#    country    year            area         activity sex age fatal_y_n  month  \
# 0      USA  2018.0         Georgia         Standing   F  11         N      6
# 1      USA  2018.0         Florida          Fishing   M  52         N      5
# 2      USA  2018.0         Florida          Walking   M  15         N      5
# 3      USA  2018.0         Florida         Standing   M  12         N      5
# 4      USA  2018.0  South Carolina  Boogie boarding   M  10         N      5
# ..     ...     ...             ...              ...  ..  ..       ...    ...
# 95     USA  2016.0  North Carolina         Standing   M  19         N      6
# 96     USA  2016.0         Florida         Swimming   M  64         N      6
# 97     USA  2016.0      California         Swimming   F  52         N      5
# 98     USA  2016.0         Florida         Swimming   M  13         N      5
# 99     USA  2016.0         Florida         Swimming   F  57         N      5
#
#    hemisph
# 0    North
# 1    North
# 2    North
# 3    North
# 4    North
# ..     ...
# 95   North
# 96   North
# 97   North
# 98   North
# 99   North
#
# [100 rows x 9 columns]

# %%
df.dtypes
# Out:
# country       object
# year         float64
# area          object
# activity      object
# sex           object
# age           object
# fatal_y_n     object
# month          int64
# hemisph       object
# dtype: object

# %%
# merged_unprovoked_df['Season'] = ''
# merged_unprovoked_df

# %%
# Adding Season column.  Source:https://stackoverflow.com/questions/30631841/how-do-i-assign-values-based-on-multiple-conditions-for-existing-columns

conditions = [
    df['hemisph'].eq('North') & df['month'].isin([11,12,1,2]),
    df['hemisph'].eq('North') & df['month'].isin([3,4,5]),
    df['hemisph'].eq('North') & df['month'].isin([6,7,8]),
    df['hemisph'].eq('North') & df['month'].isin([9,10]),
    df['hemisph'].eq('South') & df['month'].isin([11,12,1,2]),
    df['hemisph'].eq('South') & df['month'].isin([3,4,5]),
    df['hemisph'].eq('South') & df['month'].isin([6,7,8]),
    df['hemisph'].eq('South') & df['month'].isin([9,10])
]

choices = ["winter","spring","summer","fall","summer","fall","winter","spring"]

df['Season'] = np.select(conditions, choices, default=0)

df.head()
# Out:
#   country    year            area         activity sex age fatal_y_n  month  \
# 0     USA  2018.0         Georgia         Standing   F  11         N      6
# 1     USA  2018.0         Florida          Fishing   M  52         N      5
# 2     USA  2018.0         Florida          Walking   M  15         N      5
# 3     USA  2018.0         Florida         Standing   M  12         N      5
# 4     USA  2018.0  South Carolina  Boogie boarding   M  10         N      5
#
#   hemisph  Season
# 0   North  summer
# 1   North  spring
# 2   North  spring
# 3   North  spring
# 4   North  spring

# %%
df=df.to_csv('df.csv', index = False)
