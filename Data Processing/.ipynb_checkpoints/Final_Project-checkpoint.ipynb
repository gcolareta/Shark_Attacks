# %%
import pandas as pd
import numpy as np
import time
import datetime

# %%
path = 'resources/attacks.csv'

# %%
# Reading attacks dataset. Source: https://stackoverflow.com/questions/42339876/error-unicodedecodeerror-utf-8-codec-cant-decode-byte-0xff-in-position-0-in
attacks_raw_df = pd.read_csv(path, encoding='cp1252')

# %%
attacks_raw_df.head()
# Out:
#      Country Case_Number       Date    Year        Type             Area  \
# 0        USA  2018.06.25  6/25/2018  2018.0     Boating       California
# 1        USA  2018.06.18  6/18/2018  2018.0  Unprovoked          Georgia
# 2        USA  2018.06.09   6/9/2018  2018.0     Invalid           Hawaii
# 3  AUSTRALIA  2018.06.08   6/8/2018  2018.0  Unprovoked  New South Wales
# 4     MEXICO  2018.06.04   6/4/2018  2018.0    Provoked           Colima
#
#                          Location     Activity             Name Sex   Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                    Habush, Oahu      Surfing      John Denges    M   48
# 3              Arrawarra Headland      Surfing             male    M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos     M  NaN
#
#                                               Injury Fatal_Y_N           Time  \
# 0  No injury to occupant, outrigger canoe and pad...         N          18h00
# 1                         Minor injury to left thigh         N  14h00  -15h00
# 2       Injury to left lower leg from surfboard skeg         N          07h45
# 3                          Minor injury to lower leg         N            NaN
# 4  Lacerations to leg & hand shark PROVOKED INCIDENT         N            NaN
#
#           Species         Investigator_ or_ Source                       pdf  \
# 0      White shark                R. Collier, GSAF      2018.06.25-Wolfe.pdf
# 1              NaN  K.McMurray, TrackingSharks.com    2018.06.18-McNeely.pdf
# 2              NaN  K.McMurray, TrackingSharks.com     2018.06.09-Denges.pdf
# 3        2 m shark                  B. Myatt, GSAF  2018.06.08-Arrawarra.pdf
# 4  Tiger shark, 3m                       A .Kipper      2018.06.04-Ramos.pdf
#
#                                                 href
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...

# %%
# Drop irrelevant columns
attacks_df = attacks_raw_df.drop(
    ['Name', 'Investigator_ or_ Source', 'pdf', 'href'], axis=1)

# %%
attacks_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6302 entries, 0 to 6301
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Country      6252 non-null   object
#  1   Case_Number  6302 non-null   object
#  2   Date         6302 non-null   object
#  3   Year         6300 non-null   float64
#  4   Type         6298 non-null   object
#  5   Area         5847 non-null   object
#  6   Location     5762 non-null   object
#  7   Activity     5758 non-null   object
#  8   Sex          5737 non-null   object
#  9   Age          3471 non-null   object
#  10  Injury       6274 non-null   object
#  11  Fatal_Y_N    5763 non-null   object
#  12  Time         2948 non-null   object
#  13  Species      3464 non-null   object
# dtypes: float64(1), object(13)
# memory usage: 689.4+ KB

# %%
# Keep only unprovoked attacks
unprovoked_attacks_df = attacks_df[attacks_df['Type'] == "Unprovoked"]

# %%
unprovoked_attacks_df.head()
# Out:
#      Country   Case_Number       Date    Year        Type             Area  \
# 1        USA    2018.06.18  6/18/2018  2018.0  Unprovoked          Georgia
# 3  AUSTRALIA    2018.06.08   6/8/2018  2018.0  Unprovoked  New South Wales
# 5  AUSTRALIA  2018.06.03.b   6/3/2018  2018.0  Unprovoked  New South Wales
# 6     BRAZIL  2018.06.03.a   6/3/2018  2018.0  Unprovoked       Pernambuco
# 7        USA    2018.05.27  5/27/2018  2018.0  Unprovoked          Florida
#
#                                             Location      Activity Sex   Age  \
# 1                     St. Simon Island, Glynn County      Standing    F   11
# 3                                 Arrawarra Headland       Surfing    M  NaN
# 5                                 Flat Rock, Ballina  Kite surfing    M  NaN
# 6                              Piedade Beach, Recife      Swimming    M   18
# 7  Lighhouse Point Park, Ponce Inlet, Volusia County       Fishing    M   52
#
#                                     Injury Fatal_Y_N            Time  \
# 1               Minor injury to left thigh         N   14h00  -15h00
# 3                Minor injury to lower leg         N             NaN
# 5                  No injury, board bitten         N             NaN
# 6                                    FATAL         Y  Late afternoon
# 7  Minor injury to foot. PROVOKED INCIDENT         N             NaN
#
#           Species
# 1              NaN
# 3        2 m shark
# 5              NaN
# 6      Tiger shark
# 7  Lemon shark, 3'

# %%
# Add Month column to extract the month of the attack
unprovoked_attacks_df['Month'] = ''
# Out:
# /Users/giovannacolareta/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
unprovoked_attacks_df.head(5)
# Out:
#      Country   Case_Number       Date    Year        Type             Area  \
# 1        USA    2018.06.18  6/18/2018  2018.0  Unprovoked          Georgia
# 3  AUSTRALIA    2018.06.08   6/8/2018  2018.0  Unprovoked  New South Wales
# 5  AUSTRALIA  2018.06.03.b   6/3/2018  2018.0  Unprovoked  New South Wales
# 6     BRAZIL  2018.06.03.a   6/3/2018  2018.0  Unprovoked       Pernambuco
# 7        USA    2018.05.27  5/27/2018  2018.0  Unprovoked          Florida
#
#                                             Location      Activity Sex   Age  \
# 1                     St. Simon Island, Glynn County      Standing    F   11
# 3                                 Arrawarra Headland       Surfing    M  NaN
# 5                                 Flat Rock, Ballina  Kite surfing    M  NaN
# 6                              Piedade Beach, Recife      Swimming    M   18
# 7  Lighhouse Point Park, Ponce Inlet, Volusia County       Fishing    M   52
#
#                                     Injury Fatal_Y_N            Time  \
# 1               Minor injury to left thigh         N   14h00  -15h00
# 3                Minor injury to lower leg         N             NaN
# 5                  No injury, board bitten         N             NaN
# 6                                    FATAL         Y  Late afternoon
# 7  Minor injury to foot. PROVOKED INCIDENT         N             NaN
#
#           Species  Month
# 1              NaN
# 3        2 m shark
# 5              NaN
# 6      Tiger shark
# 7  Lemon shark, 3'

# %%
# Reorder columns
unprovoked_attacks_df = unprovoked_attacks_df.reindex(columns=['Case_Number', 'Date', 'Month', 'Year', 'Type', 'Country', 'Area', 'Location',
                                        'Activity', 'Sex', 'Age', 'Injury', 'Fatal_Y_N', 'Time', 'Species']
                                               )

# %%
unprovoked_attacks_df.head(5)
# Out:
#     Case_Number       Date Month    Year        Type    Country  \
# 1    2018.06.18  6/18/2018        2018.0  Unprovoked        USA
# 3    2018.06.08   6/8/2018        2018.0  Unprovoked  AUSTRALIA
# 5  2018.06.03.b   6/3/2018        2018.0  Unprovoked  AUSTRALIA
# 6  2018.06.03.a   6/3/2018        2018.0  Unprovoked     BRAZIL
# 7    2018.05.27  5/27/2018        2018.0  Unprovoked        USA
#
#               Area                                           Location  \
# 1          Georgia                     St. Simon Island, Glynn County
# 3  New South Wales                                 Arrawarra Headland
# 5  New South Wales                                 Flat Rock, Ballina
# 6       Pernambuco                              Piedade Beach, Recife
# 7          Florida  Lighhouse Point Park, Ponce Inlet, Volusia County
#
#        Activity  Sex  Age                                   Injury Fatal_Y_N  \
# 1      Standing  NaN   11               Minor injury to left thigh         N
# 3       Surfing  NaN  NaN                Minor injury to lower leg         N
# 5  Kite surfing  NaN  NaN                  No injury, board bitten         N
# 6      Swimming  NaN   18                                    FATAL         Y
# 7       Fishing  NaN   52  Minor injury to foot. PROVOKED INCIDENT         N
#
#              Time  Species
# 1   14h00  -15h00      NaN
# 3             NaN      NaN
# 5             NaN      NaN
# 6  Late afternoon      NaN
# 7             NaN      NaN

# %% [markdown]
# ## Cleaning 'Date' column

# %%
# Drop rows with a year less than 1950
unprovoked_attacks_2000 = unprovoked_attacks_df[unprovoked_attacks_df["Year"]>=2000]
unprovoked_attacks_2000.head()
# Out:
#     Case_Number       Date Month    Year        Type    Country  \
# 1    2018.06.18  6/18/2018        2018.0  Unprovoked        USA
# 3    2018.06.08   6/8/2018        2018.0  Unprovoked  AUSTRALIA
# 5  2018.06.03.b   6/3/2018        2018.0  Unprovoked  AUSTRALIA
# 6  2018.06.03.a   6/3/2018        2018.0  Unprovoked     BRAZIL
# 7    2018.05.27  5/27/2018        2018.0  Unprovoked        USA
#
#               Area                                           Location  \
# 1          Georgia                     St. Simon Island, Glynn County
# 3  New South Wales                                 Arrawarra Headland
# 5  New South Wales                                 Flat Rock, Ballina
# 6       Pernambuco                              Piedade Beach, Recife
# 7          Florida  Lighhouse Point Park, Ponce Inlet, Volusia County
#
#        Activity  Sex  Age                                   Injury Fatal_Y_N  \
# 1      Standing  NaN   11               Minor injury to left thigh         N
# 3       Surfing  NaN  NaN                Minor injury to lower leg         N
# 5  Kite surfing  NaN  NaN                  No injury, board bitten         N
# 6      Swimming  NaN   18                                    FATAL         Y
# 7       Fishing  NaN   52  Minor injury to foot. PROVOKED INCIDENT         N
#
#              Time  Species
# 1   14h00  -15h00      NaN
# 3             NaN      NaN
# 5             NaN      NaN
# 6  Late afternoon      NaN
# 7             NaN      NaN

# %%
unprovoked_attacks_2000['Month'] = unprovoked_attacks_2000['Case_Number'].str[6:7]
# Out:
# /Users/giovannacolareta/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
unprovoked_attacks_2000.head()
# Out:
#     Case_Number       Date Month    Year        Type    Country  \
# 1    2018.06.18  6/18/2018     6  2018.0  Unprovoked        USA
# 3    2018.06.08   6/8/2018     6  2018.0  Unprovoked  AUSTRALIA
# 5  2018.06.03.b   6/3/2018     6  2018.0  Unprovoked  AUSTRALIA
# 6  2018.06.03.a   6/3/2018     6  2018.0  Unprovoked     BRAZIL
# 7    2018.05.27  5/27/2018     5  2018.0  Unprovoked        USA
#
#               Area                                           Location  \
# 1          Georgia                     St. Simon Island, Glynn County
# 3  New South Wales                                 Arrawarra Headland
# 5  New South Wales                                 Flat Rock, Ballina
# 6       Pernambuco                              Piedade Beach, Recife
# 7          Florida  Lighhouse Point Park, Ponce Inlet, Volusia County
#
#        Activity  Sex  Age                                   Injury Fatal_Y_N  \
# 1      Standing  NaN   11               Minor injury to left thigh         N
# 3       Surfing  NaN  NaN                Minor injury to lower leg         N
# 5  Kite surfing  NaN  NaN                  No injury, board bitten         N
# 6      Swimming  NaN   18                                    FATAL         Y
# 7       Fishing  NaN   52  Minor injury to foot. PROVOKED INCIDENT         N
#
#              Time  Species
# 1   14h00  -15h00      NaN
# 3             NaN      NaN
# 5             NaN      NaN
# 6  Late afternoon      NaN
# 7             NaN      NaN

# %%
# Convert Month column to integer
unprovoked_attacks_2000['Month'].astype(int)
# Out:
# 1       6
# 3       6
# 5       6
# 6       6
# 7       5
#        ..
# 2071    2
# 2072    2
# 2074    2
# 2075    2
# 2077    1
# Name: Month, Length: 1617, dtype: int64

# %% [markdown]
# ## Extract the Species column

# %%
# Reading attacks dataset. Source: https://stackoverflow.com/questions/42339876/error-unicodedecodeerror-utf-8-codec-cant-decode-byte-0xff-in-position-0-in
attacks_raw_df = pd.read_csv(path, encoding='cp1252')
attacks_raw_df.head()
# Out:
#      Country Case_Number       Date    Year        Type             Area  \
# 0        USA  2018.06.25  6/25/2018  2018.0     Boating       California
# 1        USA  2018.06.18  6/18/2018  2018.0  Unprovoked          Georgia
# 2        USA  2018.06.09   6/9/2018  2018.0     Invalid           Hawaii
# 3  AUSTRALIA  2018.06.08   6/8/2018  2018.0  Unprovoked  New South Wales
# 4     MEXICO  2018.06.04   6/4/2018  2018.0    Provoked           Colima
#
#                          Location     Activity             Name Sex   Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                    Habush, Oahu      Surfing      John Denges    M   48
# 3              Arrawarra Headland      Surfing             male    M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos     M  NaN
#
#                                               Injury Fatal_Y_N           Time  \
# 0  No injury to occupant, outrigger canoe and pad...         N          18h00
# 1                         Minor injury to left thigh         N  14h00  -15h00
# 2       Injury to left lower leg from surfboard skeg         N          07h45
# 3                          Minor injury to lower leg         N            NaN
# 4  Lacerations to leg & hand shark PROVOKED INCIDENT         N            NaN
#
#           Species         Investigator_ or_ Source                       pdf  \
# 0      White shark                R. Collier, GSAF      2018.06.25-Wolfe.pdf
# 1              NaN  K.McMurray, TrackingSharks.com    2018.06.18-McNeely.pdf
# 2              NaN  K.McMurray, TrackingSharks.com     2018.06.09-Denges.pdf
# 3        2 m shark                  B. Myatt, GSAF  2018.06.08-Arrawarra.pdf
# 4  Tiger shark, 3m                       A .Kipper      2018.06.04-Ramos.pdf
#
#                                                 href
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...

# %%
species_df = attacks_raw_df.loc[['Case_Number', 'Type', 'Fatal_Y_N', 'Species']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/rj/ggvx68w91910yhv223ss9tg80000gn/T/ipykernel_55419/1908567373.py in <module>
# ----> 1 species_df = attacks_raw_df.loc[['Case_Number', 'Type', 'Fatal_Y_N', 'Species']]
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1151                     raise ValueError("Cannot index with multidimensional key")
#    1152
# -> 1153                 return self._getitem_iterable(key, axis=axis)
#    1154
#    1155             # nested tuple slicing
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
#    1091
#    1092         # A collection of keys
# -> 1093         keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1094         return self.obj._reindex_with_indexers(
#    1095             {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1372                 if use_interval_msg:
#    1373                     key = list(key)
# -> 1374                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1375
#    1376             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['Case_Number', 'Type', 'Fatal_Y_N', 'Species'], dtype='object')] are in the [index]"
